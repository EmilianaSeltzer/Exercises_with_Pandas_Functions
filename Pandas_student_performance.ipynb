# %% [markdown]
# # Analysis of the performace of students

# %%
import pandas as pd
import numpy as np

# %%
import os

# %%
os.chdir('/Users/OBPC/Downloads')
df= pd.read_csv('estudiantes_rendimiento.csv')
df
# Out:
#        gender     race        parent_edu         lunch test_course  \
# 0      female  group D  associate_degree  free/reduced        none
# 1        male  group C   bachelor_degree  free/reduced        none
# 2      female  group B       high_school      standard        none
# 3      female  group A  some_high_school      standard   completed
# 4        male  group D     master_degree      standard        none
# ...       ...      ...               ...           ...         ...
# 13995  female  group D  some_high_school      standard        none
# 13996    male  group A  some_high_school      standard   completed
# 13997    male  group A      some_college  free/reduced        none
# 13998    male  group D      some_college      standard        none
# 13999    male  group C       high_school  free/reduced        none
#
#        math_score  reading_score  writing_score
# 0              71             78           81.0
# 1              65             61           57.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14000 entries, 0 to 13999
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gender         14000 non-null  object
#  1   race           14000 non-null  object
#  2   parent_edu     14000 non-null  object
#  3   lunch          14000 non-null  object
#  4   test_course    14000 non-null  object
#  5   math_score     14000 non-null  int64
#  6   reading_score  14000 non-null  int64
#  7   writing_score  13020 non-null  float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 875.1+ KB

# %%
df.describe()
# Out:
#          math_score  reading_score  writing_score
# count  14000.000000   14000.000000   13020.000000
# mean      67.990000      70.410286      69.073425
# std       15.362014      14.204705      15.121054
# min       15.000000      25.000000      15.000000
# 25%       58.000000      61.000000      59.000000
# 50%       68.000000      71.000000      70.000000
# 75%       80.000000      80.000000      80.000000
# max      100.000000     100.000000     100.000000

# %%
df.describe(include='object')
# Out:
#        gender     race    parent_edu     lunch test_course
# count   14000    14000         14000     14000       14000
# unique      2        5             6         2           2
# top      male  group C  some_college  standard        none
# freq     7212     4476          3154      9290        9213

# %% [markdown]
# Create Categories for math_score

# %%
pd.cut??
# Out:
# Signature:
# pd.cut(
#     x,
#     bins,
#     right: 'bool' = True,
#     labels=None,
#     retbins: 'bool' = False,
#     precision: 'int' = 3,
#     include_lowest: 'bool' = False,
#     duplicates: 'str' = 'raise',
#     ordered: 'bool' = True,
# )
# Source:
# def cut(
#     x,
#     bins,
#     right: bool = True,
#     labels=None,
#     retbins: bool = False,
#     precision: int = 3,
#     include_lowest: bool = False,
#     duplicates: str = "raise",
#     ordered: bool = True,
# ):
#     """
#     Bin values into discrete intervals.
#
#     Use `cut` when you need to segment and sort data values into bins. This
#     function is also useful for going from a continuous variable to a
#     categorical variable. For example, `cut` could convert ages to groups of
#     age ranges. Supports binning into an equal number of bins, or a
#     pre-specified array of bins.
#
#     Parameters
#     ----------
#     x : array-like
# ...

# %%
pd.cut(df['math_score'],6)
# Out:
# 0          (57.5, 71.667]
# 1          (57.5, 71.667]
# 2          (57.5, 71.667]
# 3          (43.333, 57.5]
# 4         (85.833, 100.0]
#                ...
# 13995      (43.333, 57.5]
# 13996      (57.5, 71.667]
# 13997    (29.167, 43.333]
# 13998    (71.667, 85.833]
# 13999      (43.333, 57.5]
# Name: math_score, Length: 14000, dtype: category
# Categories (6, interval[float64, right]): [(14.915, 29.167] < (29.167, 43.333] < (43.333, 57.5] < (57.5, 71.667] < (71.667, 85.833] < (85.833, 100.0]]

# %%
bins= [0,39,49,59,69,89,100]

labels= ['low pass', 'high pass', 'passed', 'good', 'notable', 'outstanding']

pd.cut(df['math_score'], bins = bins, labels = labels)
# Out:
# 0          notable
# 1             good
# 2             good
# 3           passed
# 4          notable
#            ...
# 13995       passed
# 13996         good
# 13997    high pass
# 13998      notable
# 13999       passed
# Name: math_score, Length: 14000, dtype: category
# Categories (6, object): ['low pass' < 'high pass' < 'passed' < 'good' < 'notable' < 'outstanding']

# %%
df['math_score_sections'] = pd.cut(df['math_score'], bins = bins, labels = labels)

# %%
df
# Out:
#        gender     race        parent_edu         lunch test_course  \
# 0      female  group D  associate_degree  free/reduced        none
# 1        male  group C   bachelor_degree  free/reduced        none
# 2      female  group B       high_school      standard        none
# 3      female  group A  some_high_school      standard   completed
# 4        male  group D     master_degree      standard        none
# ...       ...      ...               ...           ...         ...
# 13995  female  group D  some_high_school      standard        none
# 13996    male  group A  some_high_school      standard   completed
# 13997    male  group A      some_college  free/reduced        none
# 13998    male  group D      some_college      standard        none
# 13999    male  group C       high_school  free/reduced        none
#
#        math_score  reading_score  writing_score math_score_sections
# 0              71             78           81.0             notable
# ...

# %% [markdown]
# ## Analysis of scores sections per gender

# %%
df.groupby('gender').mean(numeric_only= True)
# Out:
#         math_score  reading_score  writing_score
# gender
# female   64.794490      73.411314      73.342572
# male     70.997643      67.585691      65.053832

# %% [markdown]
# Pivot table analysis

# %%
df.pivot_table??
# Out:
# Signature:
# df.pivot_table(
#     values=None,
#     index=None,
#     columns=None,
#     aggfunc: 'AggFuncType' = 'mean',
#     fill_value=None,
#     margins: 'bool' = False,
#     dropna: 'bool' = True,
#     margins_name: 'Level' = 'All',
#     observed: 'bool | lib.NoDefault' = <no_default>,
#     sort: 'bool' = True,
# ) -> 'DataFrame'
# Docstring:
# Create a spreadsheet-style pivot table as a DataFrame.
#
# The levels in the pivot table will be stored in MultiIndex objects
# (hierarchical indexes) on the index and columns of the result DataFrame.
#
# Parameters
# ----------
# values : list-like or scalar, optional
#     Column or columns to aggregate.
# index : column, Grouper, array, or list of the previous
#     Keys to group by on the pivot table index. If a list is passed,
#     it can contain any of the other types (except list). If an array is
#     passed, it must be the same length as the data and will be used in
#     the same manner as column values.
# ...

# %%
df.pivot_table(index='gender', columns='math_score_sections', values= 'math_score', aggfunc='count')
# Out:
# C:\Users\OBPC\AppData\Local\Temp\ipykernel_9632\2937489054.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(index='gender', columns='math_score_sections', values= 'math_score', aggfunc='count')
# math_score_sections  low pass  high pass  passed  good  notable  outstanding
# gender
# female                    440        622    1185  1951     2343          247
# male                      160        444    1089  1499     3233          787

# %%
df.groupby(['math_score_sections','gender']).count()
# Out:
# C:\Users\OBPC\AppData\Local\Temp\ipykernel_9632\3198808284.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['math_score_sections','gender']).count()
#                             race  parent_edu  lunch  test_course  math_score  \
# math_score_sections gender
# low pass            female   440         440    440          440         440
#                     male     160         160    160          160         160
# high pass           female   622         622    622          622         622
#                     male     444         444    444          444         444
# passed              female  1185        1185   1185         1185        1185
#                     male    1089        1089   1089         1089        1089
# ...

# %%
df['reading_sections'] = pd.cut(df['reading_score'], bins = bins, labels = labels)

# %%
df.pivot_table(index='gender', columns='reading_sections', values= 'reading_score', aggfunc='count')
# Out:
# C:\Users\OBPC\AppData\Local\Temp\ipykernel_9632\968315683.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(index='gender', columns='reading_sections', values= 'reading_score', aggfunc='count')
# reading_sections  low pass  high pass  passed  good  notable  outstanding
# gender
# female                 136        320     643  1502     3155         1032
# male                   130        568    1368  1880     2923          343

# %%
df['writing_sections'] = pd.cut(df['writing_score'], bins = bins, labels = labels)

# %%
df.pivot_table(index='gender', columns='writing_sections', values= 'writing_score', aggfunc='count')
# Out:
# C:\Users\OBPC\AppData\Local\Temp\ipykernel_9632\2512596352.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   df.pivot_table(index='gender', columns='writing_sections', values= 'writing_score', aggfunc='count')
# writing_sections  low pass  high pass  passed  good  notable  outstanding
# gender
# female                 104        285     728  1215     3063          919
# male                   223        762    1321  1739     2428          233
